# %%
import os

print("Current working directory:")
print(os.getcwd())

print("\nFiles and folders here:")
print(os.listdir())
# Out:
# Current working directory:
# d:\Post Disaster Damage Project
#
# Files and folders here:
# ['01_data_pipeline.ipynb', 'combined images', 'disaster_dataset', 'earthquake', 'Images', 'notebooks']

# %%
import os

IMAGE_DIR = "Images"

print("Contents of Images folder:")
print(os.listdir(IMAGE_DIR))
# Out:
# Contents of Images folder:
# ['earthquake', 'fire', 'flood', 'landslide', 'normal', 'smoke']
