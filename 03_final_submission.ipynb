# %% [markdown]
# # Post-Disaster Building Damage Level Assessment
#
# Group Number: 19
# Project Title: Post-Disaster Building Damage Level Assessment
# Team Members:
#  Abhi Sanjaybhai Golakiya (Technical)
#  Avi Mistry (Figures, Tables, & Presentation)
#  Hardik Prajapati (Report)
#
# Dataset: Kaggle Disaster Damage Dataset
#
# Objective:
# To classify post-disaster building images and assess damage severity using CNNs,a meta-learner. A rule-based decision system.
